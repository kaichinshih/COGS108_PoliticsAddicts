# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
maplotlib

# %%
df = pd.read_csv('FEC_Bernie2020.csv')

# %%
df = df[['transaction_id', 'contribution_receipt_date', 'contribution_receipt_amount', 'contributor_state']]

# %%
df['contribution_receipt_date'] = df['contribution_receipt_date'].astype("datetime64")

# %%
# df.groupby(df['contribution_receipt_date'].dt.date)..plot('hist')
# Out:
#   File "<ipython-input-34-95c58a953a74>", line 1
#     df.groupby(df['contribution_receipt_date'].dt.date)..plot.hist()
#                                                         ^
# SyntaxError: invalid syntax

# %%
df['contribution_receipt_amount'] = df['contribution_receipt_amount'].apply(pd.to_numeric)
# Out:
# 2904271.2299999944

# %%
df.plot(x = 'contribution_receipt_date', y = 'contribution_receipt_amount')
